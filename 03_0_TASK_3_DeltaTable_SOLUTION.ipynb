# %%
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip

import ConnectionConfig as cc
#cc.setupEnvironment()
spark = cc.startLocalCluster("DeltaTableEx")
spark.getActiveSession()
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://sparkjupyter:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>DeltaTableEx</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#list all installed packages
print(spark.sparkContext.getConf().getAll())
# Out:
# [('spark.driver.host', 'sparkjupyter'), ('spark.hadoop.fs.s3a.vectored.read.min.seek.size', '128K'), ('spark.app.id', 'local-1757659580787'), ('spark.sql.shuffle.partitions', '4'), ('spark.app.name', 'DeltaTableEx'), ('spark.sql.artifact.isolation.enabled', 'false'), ('spark.app.submitTime', '1757659579444'), ('spark.master', 'local[*]'), ('spark.sql.warehouse.dir', 'file:/home/jovyan/work/spark-warehouse'), ('spark.jars', 'file:///home/jovyan/.ivy2.5.2/jars/io.delta_delta-spark_2.13-4.0.0.jar,file:///home/jovyan/.ivy2.5.2/jars/io.delta_delta-storage-4.0.0.jar,file:///home/jovyan/.ivy2.5.2/jars/org.antlr_antlr4-runtime-4.13.1.jar'), ('spark.executor.id', 'driver'), ('spark.app.initial.jar.urls', 'spark://sparkjupyter:33391/jars/io.delta_delta-storage-4.0.0.jar,spark://sparkjupyter:33391/jars/org.antlr_antlr4-runtime-4.13.1.jar,spark://sparkjupyter:33391/jars/io.delta_delta-spark_2.13-4.0.0.jar'), ('spark.sql.extensions', 'io.delta.sql.DeltaSparkSessionExtension'), ('spark.submit.deployMode', 'client'), ('spark.repl.local.jars', 'file:///home/jovyan/.ivy2.5.2/jars/io.delta_delta-spark_2.13-4.0.0.jar,file:///home/jovyan/.ivy2.5.2/jars/io.delta_delta-storage-4.0.0.jar,file:///home/jovyan/.ivy2.5.2/jars/org.antlr_antlr4-runtime-4.13.1.jar'), ('spark.executor.extraJavaOptions', '-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-modules=jdk.incubator.vector --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false -Dio.netty.tryReflectionSetAccessible=true -Dsasl.jaas.config=org.apache.kafka.common.security.plain.PlainLoginModule required username=RHUIVNZYHMOODAKC password=/bkAQpKgCWjkPfTgxRY973VOhKf+MmwFulZLrAdrwdlXUTta0AUvNjo/8U57R8/w; -Dsasl.mechanism=PLAIN'), ('spark.serializer.objectStreamReset', '100'), ('spark.ui.showConsoleProgress', 'true'), ('spark.app.startTime', '1757659580026'), ('spark.rdd.compress', 'True'), ('spark.driver.port', '33391'), ('spark.sql.catalog.spark_catalog', 'org.apache.spark.sql.delta.catalog.DeltaCatalog'), ('spark.app.initial.file.urls', 'file:///home/jovyan/.ivy2.5.2/jars/org.antlr_antlr4-runtime-4.13.1.jar,file:///home/jovyan/.ivy2.5.2/jars/io.delta_delta-spark_2.13-4.0.0.jar,file:///home/jovyan/.ivy2.5.2/jars/io.delta_delta-storage-4.0.0.jar'), ('spark.submit.pyFiles', '/home/jovyan/.ivy2.5.2/jars/io.delta_delta-spark_2.13-4.0.0.jar,/home/jovyan/.ivy2.5.2/jars/io.delta_delta-storage-4.0.0.jar,/home/jovyan/.ivy2.5.2/jars/org.antlr_antlr4-runtime-4.13.1.jar'), ('spark.driver.extraJavaOptions', '-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-modules=jdk.incubator.vector --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=AL ...

# %%
from delta import DeltaTable

# Step 1: Load the dataset into a Delta table
transaction_data_path = "./FileStore/tables/transactions.csv"  # Replace with the actual path to the transaction data CSV file
transaction_delta_path = "./spark-warehouse/transaction_data_delta"  # Replace with the actual path where you want to store the Delta table

# %% [markdown]
# # Persist a detlatable to disk based on the CSV transactions.csv
# Read the CSV file transaction_data_path
# Write it as a Delta table to transaction_delta_path
# Use inferSchema option (see: https://sparkbyexamples.com/pyspark/pyspark-read-csv-file-into-dataframe/) to automatically infer the schema from the CSV file. Otherwise all columns will be of type string

# %%
from pyspark.sql.types import StructType
# Read the CSV data and write it as a Delta table
df = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load(transaction_data_path)
df.write.format("delta").mode("overwrite").save(transaction_delta_path)

# %% [markdown]
# # Create a DeltaTable object for the persisted transaction data
# Use DetlaTable.forPath() to create a DeltaTable object for the persisted transaction data
# A delta table object is needed to use functions like history() and vacuum()

# %%
delta_table = DeltaTable.forPath(spark, transaction_delta_path)

# %% [markdown]
# # Get the schema and history information for the Delta table
# To get the schema get the dataframe object with toDf() and use printSchema()
# Delta table has a history() method that returns a dataframe with the history of the delta table
# Make sure you understand the results

# %%
# Get the # Ge schema and history
delta_table.toDF().printSchema()
# Out:
# root
#  |-- transaction_id: integer (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- purchase_date: date (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- quantity: integer (nullable = true)

# %%
delta_table.detail().show()
# Out:
# +------+--------------------+----+-----------+--------------------+--------------------+--------------------+----------------+-----------------+--------+-----------+----------+----------------+----------------+--------------------+
# |format|                  id|name|description|            location|           createdAt|        lastModified|partitionColumns|clusteringColumns|numFiles|sizeInBytes|properties|minReaderVersion|minWriterVersion|       tableFeatures|
# +------+--------------------+----+-----------+--------------------+--------------------+--------------------+----------------+-----------------+--------+-----------+----------+----------------+----------------+--------------------+
# | delta|14dcaffc-6f66-43d...|NULL|       NULL|file:/home/jovyan...|2024-09-17 10:09:...|2025-09-12 06:46:...|              []|               []|       1|       1823|        {}|               1|               2|[appendOnly, inva...|
# +------+--------------------+----+-----------+--------------------+--------------------+--------------------+----------------+-----------------+--------+-----------+----------+----------------+----------------+--------------------+

# %%
delta_table.history().show(vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 28
#  timestamp           | 2025-09-12 06:46:39.158
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Overwrite, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 27
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 1817, numOutputRows -> 10, numOutputBytes -> 1823}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 1-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 27
#  timestamp           | 2025-08-29 08:19:50.549
#  userId              | NULL
#  userName            | NULL
#  operation           | MERGE
#  operationParameters | {predicate -> ["(transaction_id#888 = transaction_id#4164)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 26
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetBytesRemoved -> 1769, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 7, numTargetRowsMatchedDeleted -> 0, numTargetRowsUpdated -> 7, numTargetChangeFilesAdded -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 655, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1817, executionTimeMs -> 2904, materializeSourceTimeMs -> 123, numTargetRowsInserted -> 3, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 855, numOutputRows -> 10, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numSourceRows -> 10, numTargetFilesRemoved -> 1}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 2-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 26
#  timestamp           | 2025-08-29 08:19:40.79
#  userId              | NULL
#  userName            | NULL
#  operation           | DELETE
#  operationParameters | {predicate -> ["(customer_id#889 = 101)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 25
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1817, numCopiedRows -> 7, numDeletionVectorsAdded -> 0, executionTimeMs -> 2143, numDeletionVectorsUpdated -> 0, numAddedFiles -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 3, scanTimeMs -> 1860, numAddedBytes -> 1769, rewriteTimeMs -> 282}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 3-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 25
#  timestamp           | 2025-08-29 08:19:34.282
#  userId              | NULL
#  userName            | NULL
#  operation           | UPDATE
#  operationParameters | {predicate -> ["(product_name#891 = Product A)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 24
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1823, numCopiedRows -> 6, numDeletionVectorsAdded -> 0, executionTimeMs -> 1383, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1028, numAddedFiles -> 1, numUpdatedRows -> 4, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 1817, rewriteTimeMs -> 354}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 4-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 24
#  timestamp           | 2025-08-29 08:19:21.119
#  userId              | NULL
#  userName            | NULL
# ...
#  clusterId           | NULL
#  readVersion         | 9
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 1823, numOutputRows -> 10, numOutputBytes -> 1823}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 19------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 9
#  timestamp           | 2025-08-25 16:31:13.436
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Overwrite, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 8
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 1823, numOutputRows -> 10, numOutputBytes -> 1823}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# only showing top 20 rows

# %% [markdown]
# # Create a query on the delta table to find the total number of transactions
# Use toDF() to convert the delta table to a spark dataframe

# %%
total_transactions = delta_table.toDF().count()
print(f"Total number of transactions: {total_transactions}")
# Out:
# Total number of transactions: 10

# %% [markdown]
# # Create a view on the delta table with the name 'transactions'

# %%
#Create a view on the delta table
delta_table.toDF().createOrReplaceTempView("transactions")

# %% [markdown]
# # Update the delta table to increase the quantity of a specific product by a given value
# You canw write an update statement on the delta table with spark.sql(). This is not supported without the use of delta table

# %%
# Step 5: Update the Delta table to increase the quantity of a specific product by a given value spark.sql
spark.sql("UPDATE transactions SET quantity = quantity + 1 WHERE product_name = 'Product A'").show()
# Out:
# +-----------------+
# |num_affected_rows|
# +-----------------+
# |                4|
# +-----------------+

# %% [markdown]
# # Consult the history of the Delta table again
# Try to understand what you see
# When the results are truncated, you can use the vertical option in method show() to see the full results

# %%
delta_table.history().show(truncate = False, vertical=True)
# Out:
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 29
#  timestamp           | 2025-09-12 06:46:52.354
#  userId              | NULL
#  userName            | NULL
#  operation           | UPDATE
#  operationParameters | {predicate -> ["(product_name#891 = Product A)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 28
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1823, numCopiedRows -> 6, numDeletionVectorsAdded -> 0, executionTimeMs -> 1133, numDeletionVectorsUpdated -> 0, scanTimeMs -> 827, numAddedFiles -> 1, numUpdatedRows -> 4, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 1817, rewriteTimeMs -> 305}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 1-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 28
#  timestamp           | 2025-09-12 06:46:39.158
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Overwrite, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 27
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 1817, numOutputRows -> 10, numOutputBytes -> 1823}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 2-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 27
#  timestamp           | 2025-08-29 08:19:50.549
#  userId              | NULL
#  userName            | NULL
#  operation           | MERGE
#  operationParameters | {predicate -> ["(transaction_id#888 = transaction_id#4164)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 26
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetBytesRemoved -> 1769, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 7, numTargetRowsMatchedDeleted -> 0, numTargetRowsUpdated -> 7, numTargetChangeFilesAdded -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 655, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1817, executionTimeMs -> 2904, materializeSourceTimeMs -> 123, numTargetRowsInserted -> 3, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 855, numOutputRows -> 10, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numSourceRows -> 10, numTargetFilesRemoved -> 1}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 3-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 26
#  timestamp           | 2025-08-29 08:19:40.79
#  userId              | NULL
#  userName            | NULL
#  operation           | DELETE
#  operationParameters | {predicate -> ["(customer_id#889 = 101)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 25
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1817, numCopiedRows -> 7, numDeletionVectorsAdded -> 0, executionTimeMs -> 2143, numDeletionVectorsUpdated -> 0, numAddedFiles -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 3, scanTimeMs -> 1860, numAddedBytes -> 1769, rewriteTimeMs -> 282}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 4-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 25
#  timestamp           | 2025-08-29 08:19:34.282
#  userId              | NULL
#  userName            | NULL
# ...
#  clusterId           | NULL
#  readVersion         | 10
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1823, numCopiedRows -> 6, numDeletionVectorsAdded -> 0, executionTimeMs -> 1247, numDeletionVectorsUpdated -> 0, scanTimeMs -> 958, numAddedFiles -> 1, numUpdatedRows -> 4, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 1817, rewriteTimeMs -> 287}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 19------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 10
#  timestamp           | 2025-08-26 06:54:09.044
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Overwrite, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 9
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 1823, numOutputRows -> 10, numOutputBytes -> 1823}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# only showing top 20 rows

# %% [markdown]
# # Delete all transactions from customer 101
# You canw write an delete statement on the delta table with spark.sql(). This is not supported without the use of delta table

# %%
#Delete all transactions from customer 101
spark.sql("DELETE from transactions where customer_id=101").show()
# Out:
# +-----------------+
# |num_affected_rows|
# +-----------------+
# |                3|
# +-----------------+

# %% [markdown]
# # Consult the history of the Delta table again to see what is changed

# %%
spark.sql("select * from transactions").show()
delta_table.history().show(truncate=False,vertical=True)
# Out:
# +--------------+-----------+-------------+------------+--------+
# |transaction_id|customer_id|purchase_date|product_name|quantity|
# +--------------+-----------+-------------+------------+--------+
# |             2|        102|   2023-06-02|   Product B|       5|
# |             3|        103|   2023-06-03|   Product A|       4|
# |             5|        104|   2023-06-05|   Product B|       4|
# |             6|        102|   2023-06-06|   Product A|       3|
# |             7|        103|   2023-06-07|   Product C|       3|
# |             9|        104|   2023-06-09|   Product A|       3|
# |            10|        103|   2023-06-10|   Product B|       3|
# +--------------+-----------+-------------+------------+--------+
#
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 30
#  timestamp           | 2025-09-12 06:46:58.589
#  userId              | NULL
#  userName            | NULL
#  operation           | DELETE
#  operationParameters | {predicate -> ["(customer_id#889 = 101)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 29
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1817, numCopiedRows -> 7, numDeletionVectorsAdded -> 0, executionTimeMs -> 1942, numDeletionVectorsUpdated -> 0, numAddedFiles -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 3, scanTimeMs -> 1725, numAddedBytes -> 1769, rewriteTimeMs -> 217}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 1-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 29
#  timestamp           | 2025-09-12 06:46:52.354
#  userId              | NULL
#  userName            | NULL
#  operation           | UPDATE
#  operationParameters | {predicate -> ["(product_name#891 = Product A)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 28
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1823, numCopiedRows -> 6, numDeletionVectorsAdded -> 0, executionTimeMs -> 1133, numDeletionVectorsUpdated -> 0, scanTimeMs -> 827, numAddedFiles -> 1, numUpdatedRows -> 4, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 1817, rewriteTimeMs -> 305}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 2-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 28
#  timestamp           | 2025-09-12 06:46:39.158
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Overwrite, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 27
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 1817, numOutputRows -> 10, numOutputBytes -> 1823}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 3-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 27
#  timestamp           | 2025-08-29 08:19:50.549
#  userId              | NULL
#  userName            | NULL
#  operation           | MERGE
#  operationParameters | {predicate -> ["(transaction_id#888 = transaction_id#4164)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 26
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetBytesRemoved -> 1769, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 7, numTargetRowsMatchedDeleted -> 0, numTargetRowsUpdated -> 7, numTargetChangeFilesAdded -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 655, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1817, executionTimeMs -> 2904, materializeSourceTimeMs -> 123, numTargetRowsInserted -> 3, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 855, numOutputRows -> 10, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numSourceRows -> 10, numTargetFilesRemoved -> 1}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 4-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 26
#  timestamp           | 2025-08-29 08:19:40.79
#  userId              | NULL
# ...
#  clusterId           | NULL
#  readVersion         | 11
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1817, numCopiedRows -> 7, numDeletionVectorsAdded -> 0, executionTimeMs -> 2391, numDeletionVectorsUpdated -> 0, numAddedFiles -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 3, scanTimeMs -> 2096, numAddedBytes -> 1769, rewriteTimeMs -> 295}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 19------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 11
#  timestamp           | 2025-08-26 06:54:39.15
#  userId              | NULL
#  userName            | NULL
#  operation           | UPDATE
#  operationParameters | {predicate -> ["(product_name#1654 = Product A)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 10
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1823, numCopiedRows -> 6, numDeletionVectorsAdded -> 0, executionTimeMs -> 1247, numDeletionVectorsUpdated -> 0, scanTimeMs -> 958, numAddedFiles -> 1, numUpdatedRows -> 4, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 1817, rewriteTimeMs -> 287}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# only showing top 20 rows

# %% [markdown]
# # Perform an merge operation
# Get info on merge operations: https://docs.delta.io/latest/delta-update.html#upsert-into-a-table-using-merge&language-sql
# 1. Create a new dataframe original_df that reads the original transaction data from the CSV file and create a temporary view 'original_transactions'
# 2. Perform a merge of  'original_transactions' into 'transactions'
# 3. When a match is found, update the quantity for that row to 0
# 4. When no match is found, insert the row from the new dataframe

# %%
# Step 6: Perform an upsert
original_df =spark.read.format("csv").options(header="true", inferSchema="true").load(transaction_data_path)
original_df.createOrReplaceTempView("original_transactions")

spark.sql("MERGE INTO transactions AS target \
          using original_transactions AS source ON target.transaction_id = source.transaction_id \
          WHEN MATCHED THEN UPDATE SET quantity = 0 \
          WHEN NOT MATCHED THEN INSERT *")
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %% [markdown]
# # Show the detla table and detla table history
# Is the result what you expected?

# %%
delta_table.toDF().show()
# Out:
# +--------------+-----------+-------------+------------+--------+
# |transaction_id|customer_id|purchase_date|product_name|quantity|
# +--------------+-----------+-------------+------------+--------+
# |             1|        101|   2023-06-01|   Product A|       2|
# |             2|        102|   2023-06-02|   Product B|       0|
# |             3|        103|   2023-06-03|   Product A|       0|
# |             4|        101|   2023-06-04|   Product C|       1|
# |             5|        104|   2023-06-05|   Product B|       0|
# |             6|        102|   2023-06-06|   Product A|       0|
# |             7|        103|   2023-06-07|   Product C|       0|
# |             8|        101|   2023-06-08|   Product B|       5|
# |             9|        104|   2023-06-09|   Product A|       0|
# |            10|        103|   2023-06-10|   Product B|       0|
# +--------------+-----------+-------------+------------+--------+

# %%
delta_table.history().show(vertical=True, truncate=False)
# Out:
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 31
#  timestamp           | 2025-09-12 06:47:10.101
#  userId              | NULL
#  userName            | NULL
#  operation           | MERGE
#  operationParameters | {predicate -> ["(transaction_id#888 = transaction_id#4939)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 30
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetBytesRemoved -> 1769, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 7, numTargetRowsMatchedDeleted -> 0, numTargetRowsUpdated -> 7, numTargetChangeFilesAdded -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 535, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1817, executionTimeMs -> 2286, materializeSourceTimeMs -> 73, numTargetRowsInserted -> 3, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 544, numOutputRows -> 10, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numSourceRows -> 10, numTargetFilesRemoved -> 1}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 1-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 30
#  timestamp           | 2025-09-12 06:46:58.589
#  userId              | NULL
#  userName            | NULL
#  operation           | DELETE
#  operationParameters | {predicate -> ["(customer_id#889 = 101)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 29
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1817, numCopiedRows -> 7, numDeletionVectorsAdded -> 0, executionTimeMs -> 1942, numDeletionVectorsUpdated -> 0, numAddedFiles -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 3, scanTimeMs -> 1725, numAddedBytes -> 1769, rewriteTimeMs -> 217}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 2-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 29
#  timestamp           | 2025-09-12 06:46:52.354
#  userId              | NULL
#  userName            | NULL
#  operation           | UPDATE
#  operationParameters | {predicate -> ["(product_name#891 = Product A)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 28
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1823, numCopiedRows -> 6, numDeletionVectorsAdded -> 0, executionTimeMs -> 1133, numDeletionVectorsUpdated -> 0, scanTimeMs -> 827, numAddedFiles -> 1, numUpdatedRows -> 4, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 1817, rewriteTimeMs -> 305}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 3-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 28
#  timestamp           | 2025-09-12 06:46:39.158
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Overwrite, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 27
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 1817, numOutputRows -> 10, numOutputBytes -> 1823}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 4-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 27
#  timestamp           | 2025-08-29 08:19:50.549
#  userId              | NULL
#  userName            | NULL
# ...
#  clusterId           | NULL
#  readVersion         | 12
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetBytesRemoved -> 1769, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 7, numTargetRowsMatchedDeleted -> 0, numTargetRowsUpdated -> 7, numTargetChangeFilesAdded -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 587, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1817, executionTimeMs -> 1934, materializeSourceTimeMs -> 139, numTargetRowsInserted -> 3, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 784, numOutputRows -> 10, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numSourceRows -> 10, numTargetFilesRemoved -> 1}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# -RECORD 19------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 12
#  timestamp           | 2025-08-26 06:54:48.981
#  userId              | NULL
#  userName            | NULL
#  operation           | DELETE
#  operationParameters | {predicate -> ["(customer_id#1652 = 101)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 11
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1817, numCopiedRows -> 7, numDeletionVectorsAdded -> 0, executionTimeMs -> 2391, numDeletionVectorsUpdated -> 0, numAddedFiles -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 3, scanTimeMs -> 2096, numAddedBytes -> 1769, rewriteTimeMs -> 295}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/4.0.0 Delta-Lake/4.0.0
# only showing top 20 rows

# %% [markdown]
# # Perform a select on the delta table on the second version
# Use option versionAsOf when reading (spark.read) the delta table from disk
# You can also travel back in time with option timestampAsOf

# %%
df = spark.read.format("delta").option("versionAsOf", 13).load("./spark-warehouse/transaction_data_delta")
df.show()
# Out:
# +--------------+-----------+-------------+------------+--------+
# |transaction_id|customer_id|purchase_date|product_name|quantity|
# +--------------+-----------+-------------+------------+--------+
# |             1|        101|   2023-06-01|   Product A|       2|
# |             2|        102|   2023-06-02|   Product B|       0|
# |             3|        103|   2023-06-03|   Product A|       0|
# |             4|        101|   2023-06-04|   Product C|       1|
# |             5|        104|   2023-06-05|   Product B|       0|
# |             6|        102|   2023-06-06|   Product A|       0|
# |             7|        103|   2023-06-07|   Product C|       0|
# |             8|        101|   2023-06-08|   Product B|       5|
# |             9|        104|   2023-06-09|   Product A|       0|
# |            10|        103|   2023-06-10|   Product B|       0|
# +--------------+-----------+-------------+------------+--------+

# %%
spark.stop()
